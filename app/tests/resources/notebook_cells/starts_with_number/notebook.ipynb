# %%
# 3 items input data python
list1 = ["0001", "0010", "0011"]

# %%
# three items input data python
list2 = ["0001", "0010", "0011"]

# %%
# use second list python
print(list1)
print(list2)
# Out:
# ['0001', '0010', '0011']
# ['0001', '0010', '0011']

# %%
# parameter
param_neg_string <- "-1"
param_neg_num <- -2
param_neg_decimal <- -1.5

# %%
# init var
io <- 1

# %%
# printer
print(param_neg_string)
print(io)
print(param_neg_num)
print(param_neg_decimal)
# Out:
# [1] "-1"
# [1] 1
# [1] -2
# [1] -1.5

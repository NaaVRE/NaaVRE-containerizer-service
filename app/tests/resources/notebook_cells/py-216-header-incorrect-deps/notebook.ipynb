# %%
# Bug header empty cell
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: String
# ...

# %%
# Bug header not empty cell
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: String
# ...

# %%
# cell with incorrect override header 1
# ---
# NaaVRE:
#  cell:
#   dependencies:
#    - matplotlib
# ...

print("salve")

# %%
# cell with incorrect indentation override header 2
# ---
# NaaVRE:
# cell:
#   outputs:
#    - foo: String
# ...

# %%
# cell with incorrect override header 3
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: integer
# ...

# %%
# cell with incorrect override header 4
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: list
# ...

# %%
# cell with incorrect override header 5
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: float
# ...

# %%
# cell with incorrect override header 3
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: Int
# ...

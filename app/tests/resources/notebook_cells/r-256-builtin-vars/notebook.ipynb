# %%
# Reserved variables in R
library(dplyr)
m <- 10
# Recognized reserved variables
var <- TRUE
var <- FALSE
var <- NULL
var <- Inf
var <- NaN
var <- NA
# Unrecognized reserved variables
var <- NA_integer_
var <- NA_real_
var <- NA_complex_
var <- NA_character_
var <- mtcars %>% mutate(disp = .data$disp * .env$m)

# %%
# Bug header empty cell
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: String
# ...

# %%
# Bug header not empty cell
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: String
# ...

# %%
# cell with incorrect override header 1
# ---
# NaaVRE:
#  cell:
#   dependencies:
#    - matplotlib
# ...

print("salve")

# %%
# cell with incorrect override header 2
# ---
# NaaVRE:
# cell:
#   outputs:
#    - foo: String
# ...

# %%
# Bug header empty cell
# ---
# NaaVRE:
#  cell:
#   outputs:
#    - foo: integer
# ...

# %%
# Bug header wrong param
# ---
# NaaVRE:
#  cell:
#   params:
#    - par_something:
#       type: String
#       default_value: "my default value"
# ...

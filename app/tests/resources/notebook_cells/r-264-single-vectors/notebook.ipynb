# %%
# n2 vector
dummy_n2 <- list()
dummy_n2 <- c("asdf","qwer")

# %%
# n1 vector
dummy_n1 <- list()
dummy_n1 <- c("zxcv")

# %%
# n1 list
dummy_n1 <- c("zxcv")

# %%
# print items in vector n2
print_content <- function(string_) {
  print(string_)
}

purrr::map(dummy_n2, print_content)

# %%
# print items in vector n1
print_content <- function(string_) {
  print(string_)
}

purrr::map(dummy_n1, print_content)

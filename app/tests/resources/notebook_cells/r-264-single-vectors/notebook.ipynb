# %%
# n2 vector
dummy_n2 <- list()
dummy_n2 <- c("asdf","qwer")

# %%
# n1 vector
dummy_n1 <- list()
dummy_n1 <- c("zxcv")

# %%
# print items in vector n2
print(dummy_n2)

# %%
# print items in vector n1
print(dummy_n1)

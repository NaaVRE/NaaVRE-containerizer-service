# %%
# create io
io1 <- 1

# %%
# Code with function with uunamed argument
read_acolite_files <- function(station, ...){
    extra_args <- list(...)
    print(station)
    print(extra_args)
}


read_acolite_files("cloud42", "cloud95", "cloud144")
print(io1)
